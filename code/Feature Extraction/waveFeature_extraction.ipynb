# %%
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis
from scipy.fft import fft
from scipy.signal import find_peaks, welch
from scipy.signal import butter, filtfilt
import ast
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv(r'C:\Users\rodge\OneDrive\Desktop\SML\Group Project\comp90051\data\rawData\processedData\waveform_decode_data\5c644be5c278761c.csv')

# %% [markdown]
# ## Explore GE_ART Wave data and features

# %%
GE_ART = df[df['mg_name'] == 'GE_ART'].reset_index(drop=True)
GE_ART.loc[:,'binwave'] = GE_ART['binwave'].apply(lambda x: np.array(ast.literal_eval(x)))

# %%
ART = GE_ART['binwave']
ART_signal = np.concatenate(ART[:].values)

# %%
# Plot the raw signal frequency spectrum
fft_values = np.fft.fft(ART_signal)
fft_freq = np.fft.fftfreq(len(ART_signal), 1/180)

# only keep the positive frequencies
mask = fft_freq >= 0

plt.figure(figsize=(8, 6))
plt.plot(fft_freq[:len(fft_freq)//2], np.abs(fft_values[:len(fft_values)//2]))  # 只画正频率部分
plt.title("Frequency Spectrum before Data cleaning") 
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.grid(True)
plt.show()

# %% [markdown]
# The result shows that there are two extreme low frequency and high frequency on two sides. We believe that is causing by tthe noise data such as external electromagnetic Interference or internal baeline drift.

# %%
def ARC_butter_bandpass(lowcut, highcut, fs, order):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

def ARC_bandpass_filter(data, lowcut,highcut, fs, order):

    b,a = ARC_butter_bandpass(lowcut, highcut, fs, order)
    y = filtfilt(b, a, data)
    return y

fs = 180 # 180hz
ARC_lowcut = 10
ARC_highcut = 25
ARC_order = 6

ART_signal_filtered = ARC_bandpass_filter(ART_signal, ARC_lowcut, ARC_highcut, fs, ARC_order)

# %%
fft_values = np.fft.fft(ART_signal_filtered)
fft_freq = np.fft.fftfreq(len(ART_signal_filtered), 1/180)

mask = fft_freq >= 0


plt.figure(figsize=(8, 6))
plt.plot(fft_freq[:len(fft_freq)//2], np.abs(fft_values[:len(fft_values)//2]))  # 只画正频率部分
plt.title("Frequency Spectrum after High-pass Filtering")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.grid(True)
plt.show()

# %% [markdown]
# The result output shows that We had successfully using bandpass filter the nosie data.

# %%
# Signal plot before and after filtered signals
plt.figure(figsize=(10, 6))
plt.plot(ART_signal[:fs * 10], label='Original Signal')  # 取前10秒
plt.plot(ART_signal_filtered[:fs * 10], label='Filtered Signal', linestyle='--')  # 取前10秒
plt.title('Comparison of Original and Filtered Signals (First 10 Seconds)')
plt.xlabel('Sample index')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()

# %%
fs = 180 
# 1- 
seconds = 10 

# just randomly choose a start time during the surgery
start_time = 1290

signal_to_plot_filtered= ART_signal_filtered[start_time:start_time+fs * seconds]
signal_to_plot_original = ART_signal[start_time:start_time+fs * seconds]

# create the time axis
time_axis = np.linspace(0, seconds, len(signal_to_plot_filtered))

plt.figure(figsize=(12, 6))
# plot the signal after the bandpass filter
plt.subplot(1, 2, 1)

plt.plot(time_axis, signal_to_plot_filtered, label="Filtered Signal", color='orange')
plt.title('ART Signal after Bandpass Filtering')
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
plt.grid(True)

# plot the signal before the bandpass filter
plt.subplot(1, 2, 2) 
plt.plot(time_axis, signal_to_plot_original, label="Filtered Signal", color='blue')
plt.title('ART Signal before Bandpass Filtering')
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Then, using fourier transform to extract the frequency domain features
def ARC_compute_fft(signal, fs):

    n = len(signal)
    window = np.hamming(n)
    signal = signal * window
    fft_values = np.fft.fft(signal)


    fft_freq = np.fft.fftfreq(n, d=1/fs)

    return fft_freq[:n//2], np.abs(fft_values[:n//2])

# calculate the frequency domain features
def ARC_extract_frequency_features(signal,fft_values, fft_freq, fs):

    peaks, _ = find_peaks(signal, height=np.mean(signal))
    troughs, _ = find_peaks(-signal)

    if len(peaks) > 0 and len(troughs) > 0:
         systolic_peak = np.mean(signal[peaks])
         diastolic_peak = np.mean(signal[troughs])
         pulse_amplitude = systolic_peak - diastolic_peak

    else:
        systolic_peak = 0
        diastolic_peak = 0
        pulse_amplitude = 0

    peak_frequency = fft_freq[np.argmax(fft_values)]    
    spectral_energy = np.mean(fft_values**2)
    bandwidth = np.max(fft_freq[fft_values > np.median(fft_values)])

    return {
        'systolic_peak': systolic_peak,
        'diastolic_peak': diastolic_peak,
        'pulse_amplitude': pulse_amplitude,
        'peak_frequency': peak_frequency,
        'spectral_energy': spectral_energy,
        'bandwidth': bandwidth
    }

# store the features in a list
def ARC_features(ART_signal, fs, order):

    filtered_signal = ARC_bandpass_filter(ART_signal, lowcut=0.5, highcut=20, fs = fs, order = order)

    fft_freq, fft_values = ARC_compute_fft(filtered_signal, fs = fs)
    freq_features = ARC_extract_frequency_features(fft_values,fft_values, fft_freq, fs)

    result_array = [round(float(val),2) for val in freq_features.values()]

    return result_array

fs = 180 # 180hz
ARC_lowcut = 10
ARC_highcut = 25
ARC_order = 6

result = ARC_features(ART_signal, fs, ARC_order)
print(result)
# Out:
# [5048.01, 633.42, 4414.6, 7.36, 4575890.55, 45.34]

# %% [markdown]
# The result shows a extreme high value of systolic peak and diastolic peak, these may cause by there are still lots of nosie data contained in the dataset that we havn't have ability to clean it.

# %% [markdown]
# ## Explore GE_ECG wave

# %%
GE_ECG = df[df['mg_name'] == 'GE_ECG'].reset_index(drop=True)
GE_ECG.loc[:,'binwave'] = GE_ECG['binwave'].apply(lambda x: np.array(ast.literal_eval(x)))
ECG = GE_ECG['binwave']
ECG_signal = np.concatenate(ECG[:].values)
ECG_signal
# Out:
# array([ 1653., -1243.,  1579., ..., -1555.,  1864., -1562.])

# %%
# Plot the raw signal frequency spectrum
fft_values = np.fft.fft(ECG_signal)
fft_freq = np.fft.fftfreq(len(ECG_signal), 1/180)

# only keep the positive frequencies
mask = fft_freq >= 0

plt.figure(figsize=(8, 6))
plt.plot(fft_freq[:len(fft_freq)//2], np.abs(fft_values[:len(fft_values)//2]))  
plt.title("Frequency Spectrum before Data cleaning") 
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.grid(True)
plt.show()

# %% [markdown]
# The plots results are extremely high on both sides which indiciates tha exist of noise data which requires to filter out

# %%
fs = 180 # 180hz
ECG_lowcut = 1
ECG_highcut = 12
ECG_order = 6

def ECG_butter_bandpass(lowcut, highcut, fs, order):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

def ECG_bandpass_filter(data, lowcut,highcut, fs, order):

    b,a = ECG_butter_bandpass(lowcut, highcut, fs, order=order)
    y = filtfilt(b, a, data)
    return y


ECG_signal_filtered = ECG_bandpass_filter(ECG_signal, ECG_lowcut, ECG_highcut, fs, ECG_order)

# %%
fft_values = np.fft.fft(ECG_signal_filtered)
fft_freq = np.fft.fftfreq(len(ECG_signal_filtered), 1/180)

mask = fft_freq >= 0


plt.figure(figsize=(8, 6))
plt.plot(fft_freq[:len(fft_freq)//2], np.abs(fft_values[:len(fft_values)//2]))  # 只画正频率部分
plt.title("Frequency Spectrum after High-pass Filtering")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.grid(True)
plt.show()

# %%
# Hz:180
fs = 180 
# 10 seconds of time window 
seconds = 10 

# just randomly choose a start time during the surgery
start_time = 24314

signal_to_plot_filtered= ECG_signal_filtered[start_time:start_time+fs * seconds]
signal_to_plot_original = ECG_signal[start_time:start_time+fs * seconds]

# create the time axis
time_axis = np.linspace(0, seconds, len(signal_to_plot_filtered))

plt.figure(figsize=(12, 6))
# plot the signal after the bandpass filter
plt.subplot(1, 2, 1)

plt.plot(time_axis, signal_to_plot_filtered, label="Filtered Signal", color='orange')
plt.title('ECG Signal after Bandpass Filtering')
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
plt.grid(True)

# plot the signal before the bandpass filter
plt.subplot(1, 2, 2) 
plt.plot(time_axis, signal_to_plot_original, label="Filtered Signal", color='blue')
plt.title('ECG Signal before Bandpass Filtering')
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Explore frequency domain features from ECG

# %%
def ECG_extract_features(signal,fs):


    #set the number of samples that equals to 5 seconds of time windows
    nperseg = int(750)
    freqs, psd = welch(signal, fs=fs, nperseg=nperseg)

    # extract features based on frequency components
    qrs_mask = (freqs >= 1) & (freqs <= 20)
    vf_mask = (freqs >= 4) & (freqs <= 7)
    vt_msg_mask = (freqs < 4)

    # compute the power in each frequency band
    # Chhose the mean value of the power in the frequency since different patient may have different surgery time
    qrs_freq_power = np.mean(psd[qrs_mask])
    vf_freq_power = np.mean(psd[vf_mask])
    vt_freq_power = np.mean(psd[vt_msg_mask])

    qrs_peak_freq = freqs[np.argmax(psd[qrs_mask])]

    # additional statistical features
    magnitude = np.abs(signal)
    std_magnitude = np.std(magnitude)

    return {
        'qrs_freq_power': qrs_freq_power,
        'vf_freq_power': vf_freq_power,
        'vt_freq_power': vt_freq_power,
        'qrs_peak_freq': qrs_peak_freq,
        'std_magnitude': std_magnitude
    }

# %%
ECG_signal_filtered = ECG_bandpass_filter(ECG_signal, ECG_lowcut, ECG_highcut, fs, ECG_order)
result = ECG_extract_features(ECG_signal_filtered, fs)
result = [round(float(val),2) for val in result.values()]
print(result)
# Out:
# [2.06, 3.55, 3.42, 0.24, 7.59]

# %% [markdown]
# ### Create function to using loops to extract features from every files

# %%
folder_path = r'C:\Users\rodge\OneDrive\Desktop\SML\Group Project\comp90051\data\rawData\processedData\waveform_decode_data'

columns = ['LOG_ID','ARC_wavefeature','ECG_wavefeature']

output_df = pd.DataFrame(columns=columns)

i = 1
for file in os.listdir(folder_path):
    df = pd.read_csv(os.path.join(folder_path, file))
   
    # Used the code from previous cells to extract the ART signal features
    GE_ART = df[df['mg_name'] == 'GE_ART'].reset_index(drop=True)
    GE_ART.loc[:,'binwave'] = GE_ART['binwave'].apply(lambda x: np.array(ast.literal_eval(x)))
    ART = GE_ART['binwave']
    ART_signal = np.concatenate(ART[:].values)

    fs = 180 # 180hz
    ARC_lowcut = 10
    ARC_highcut = 25
    ARC_order = 6
    ARC_result = ARC_features(ART_signal, fs, ARC_order)


    # Used the code from previous cells to extract the ECG signal features
    GE_ECG = df[df['mg_name'] == 'GE_ECG'].reset_index(drop=True)
    GE_ECG.loc[:,'binwave'] = GE_ECG['binwave'].apply(lambda x: np.array(ast.literal_eval(x)))
    ECG = GE_ECG['binwave']
    ECG_signal = np.concatenate(ECG[:].values)

    fs = 180 # 180hz
    ECG_lowcut = 1
    ECG_highcut = 12
    ECG_order = 6
    ECG_signal_filtered = ECG_bandpass_filter(ECG_signal, ECG_lowcut, ECG_highcut, fs, ECG_order)
    ECG_result = ECG_extract_features(ECG_signal_filtered, fs)
    ECG_result = [round(float(val),2) for val in ECG_result.values()]

    file_name = os.path.splitext(file)[0]

    # store the features result in the dataframe based on the file name
    new_row = pd.DataFrame({'LOG_ID': [file_name], 'ARC_wavefeature': [ARC_result], 'ECG_wavefeature': [ECG_result]})
    output_df = pd.concat([output_df, new_row], ignore_index=True)  

    i = i+1
    print(f"Currently, {i} files have been processed")
# Out:
# Currently, 2 files have been processed
# Currently, 3 files have been processed
# Currently, 4 files have been processed
# Currently, 5 files have been processed
# Currently, 6 files have been processed
# Currently, 7 files have been processed
# Currently, 8 files have been processed
# Currently, 9 files have been processed
# Currently, 10 files have been processed
# Currently, 11 files have been processed
# Currently, 12 files have been processed
# Currently, 13 files have been processed
# Currently, 14 files have been processed
# Currently, 15 files have been processed
# Currently, 16 files have been processed
# Currently, 17 files have been processed
# Currently, 18 files have been processed
# Currently, 19 files have been processed
# Currently, 20 files have been processed
# Currently, 21 files have been processed
# Currently, 22 files have been processed
# Currently, 23 files have been processed
# Currently, 24 files have been processed
# Currently, 25 files have been processed
# Currently, 26 files have been processed
# Currently, 27 files have been processed
# Currently, 28 files have been processed
# Currently, 29 files have been processed
# Currently, 30 files have been processed
# Currently, 31 files have been processed
# Currently, 32 files have been processed
# Currently, 33 files have been processed
# Currently, 34 files have been processed
# Currently, 35 files have been processed
# Currently, 36 files have been processed
# Currently, 37 files have been processed
# Currently, 38 files have been processed
# Currently, 39 files have been processed
# Currently, 40 files have been processed
# Currently, 41 files have been processed
# Currently, 42 files have been processed
# Currently, 43 files have been processed
# Currently, 44 files have been processed
# Currently, 45 files have been processed
# Currently, 46 files have been processed
# Currently, 47 files have been processed
# Currently, 48 files have been processed
# Currently, 49 files have been processed
# Currently, 50 files have been processed
# Currently, 51 files have been processed
# Currently, 52 files have been processed
# Currently, 53 files have been processed
# Currently, 54 files have been processed
# Currently, 55 files have been processed
# Currently, 56 files have been processed
# Currently, 57 files have been processed
# Currently, 58 files have been processed
# Currently, 59 files have been processed
# Currently, 60 files have been processed
# Currently, 61 files have been processed
# Currently, 62 files have been processed
# Currently, 63 files have been processed
# Currently, 64 files have been processed
# Currently, 65 files have been processed
# Currently, 66 files have been processed
# Currently, 67 files have been processed
# Currently, 68 files have been processed
# Currently, 69 files have been processed
# Currently, 70 files have been processed
# Currently, 71 files have been processed
# Currently, 72 files have been processed
# Currently, 73 files have been processed
# Currently, 74 files have been processed
# Currently, 75 files have been processed
# Currently, 76 files have been processed
# Currently, 77 files have been processed
# Currently, 78 files have been processed
# Currently, 79 files have been processed
# Currently, 80 files have been processed
# Currently, 81 files have been processed
# Currently, 82 files have been processed
# Currently, 83 files have been processed
# Currently, 84 files have been processed
# Currently, 85 files have been processed
# Currently, 86 files have been processed
# Currently, 87 files have been processed
# Currently, 88 files have been processed
# Currently, 89 files have been processed
# Currently, 90 files have been processed
# Currently, 91 files have been processed
# Currently, 92 files have been processed
# Currently, 93 files have been processed
# Currently, 94 files have been processed
# Currently, 95 files have been processed
# Currently, 96 files have been processed
# Currently, 97 files have been processed
# Currently, 98 files have been processed
# Currently, 99 files have been processed
# Currently, 100 files have been processed
# Currently, 101 files have been processed
# Currently, 102 files have been processed
# Currently, 103 files have been processed
# Currently, 104 files have been processed
# Currently, 105 files have been processed
# Currently, 106 files have been processed
# Currently, 107 files have been processed
# Currently, 108 files have been processed
# Currently, 109 files have been processed
# Currently, 110 files have been processed
# Currently, 111 files have been processed
# Currently, 112 files have been processed
# Currently, 113 files have been processed
# Currently, 114 files have been processed
# Currently, 115 files have been processed
# Currently, 116 files have been processed
# Currently, 117 files have been processed
# Currently, 118 files have been processed
# Currently, 119 files have been processed
# Currently, 120 files have been processed
# Currently, 121 files have been processed
# Currently, 122 files have been processed
# Currently, 123 files have been processed
# Currently, 124 files have been processed
# Currently, 125 files have been processed
# Currently, 126 files have been processed
# Currently, 127 files have been processed
# Currently, 128 files have been processed
# Currently, 129 files have been processed
# Currently, 130 files have been processed
# Currently, 131 files have been processed
# Currently, 132 files have been processed
# Currently, 133 files have been processed
# Currently, 134 files have been processed
# Currently, 135 files have been processed
# Currently, 136 files have been processed
# Currently, 137 files have been processed
# Currently, 138 files have been processed
# Currently, 139 files have been processed
# Currently, 140 files have been processed
# Currently, 141 files have been processed
# Currently, 142 files have been processed
# Currently, 143 files have been processed
# Currently, 144 files have been processed
# Currently, 145 files have been processed
# Currently, 146 files have been processed
# Currently, 147 files have been processed
# Currently, 148 files have been processed
# Currently, 149 files have been processed
# Currently, 150 files have been processed
# Currently, 151 files have been processed
# Currently, 152 files have been processed
# Currently, 153 files have been processed
# Currently, 154 files have been processed
# Currently, 155 files have been processed
# Currently, 156 files have been processed
# Currently, 157 files have been processed
# Currently, 158 files have been processed
# Currently, 159 files have been processed
# Currently, 160 files have been processed
# Currently, 161 files have been processed
# Currently, 162 files have been processed
# Currently, 163 files have been processed
# Currently, 164 files have been processed
# Currently, 165 files have been processed
# Currently, 166 files have been processed
# Currently, 167 files have been processed
# Currently, 168 files have been processed
# Currently, 169 files have been processed
# Currently, 170 files have been processed
# Currently, 171 files have been processed
# Currently, 172 files have been processed
# Currently, 173 files have been processed
# Currently, 174 files have been processed
# Currently, 175 files have been processed
# Currently, 176 files have been processed
# Currently, 177 files have been processed
# Currently, 178 files have been processed
# Currently, 179 files have been processed
# Currently, 180 files have been processed
# Currently, 181 files have been processed
# Currently, 182 files have been processed
# Currently, 183 files have been processed
# Currently, 184 files have been processed
# Currently, 185 files have been processed
# Currently, 186 files have been processed
# Currently, 187 files have been processed
# Currently, 188 files have been processed
# Currently, 189 files have been processed
# Currently, 190 files have been processed
# Currently, 191 files have been processed
# Currently, 192 files have been processed
# Currently, 193 files have been processed
# Currently, 194 files have been processed
# Currently, 195 files have been processed
# Currently, 196 files have been processed
# Currently, 197 files have been processed
# Currently, 198 files have been processed
# Currently, 199 files have been processed
# Currently, 200 files have been processed
# Currently, 201 files have been processed
# Currently, 202 files have been processed
# Currently, 203 files have been processed
# Currently, 204 files have been processed
# Currently, 205 files have been processed
# Currently, 206 files have been processed
# Currently, 207 files have been processed
# Currently, 208 files have been processed
# Currently, 209 files have been processed
# Currently, 210 files have been processed
# Currently, 211 files have been processed
# Currently, 212 files have been processed
# Currently, 213 files have been processed
# Currently, 214 files have been processed
# Currently, 215 files have been processed
# Currently, 216 files have been processed
# Currently, 217 files have been processed
# Currently, 218 files have been processed
# Currently, 219 files have been processed
# Currently, 220 files have been processed
# Currently, 221 files have been processed
# Currently, 222 files have been processed
# Currently, 223 files have been processed
# Currently, 224 files have been processed
# Currently, 225 files have been processed
# Currently, 226 files have been processed
# Currently, 227 files have been processed
# Currently, 228 files have been processed
# Currently, 229 files have been processed
# Currently, 230 files have been processed
# Currently, 231 files have been processed
# Currently, 232 files have been processed
# Currently, 233 files have been processed
# Currently, 234 files have been processed
# Currently, 235 files have been processed
# Currently, 236 files have been processed
# Currently, 237 files have been processed
# Currently, 238 files have been processed
# Currently, 239 files have been processed
# Currently, 240 files have been processed
# Currently, 241 files have been processed
# Currently, 242 files have been processed
# Currently, 243 files have been processed
# Currently, 244 files have been processed
# Currently, 245 files have been processed
# Currently, 246 files have been processed
# Currently, 247 files have been processed
# Currently, 248 files have been processed
# Currently, 249 files have been processed
# Currently, 250 files have been processed
# Currently, 251 files have been processed
# Currently, 252 files have been processed
# Currently, 253 files have been processed
# Currently, 254 files have been processed
# Currently, 255 files have been processed
# Currently, 256 files have been processed
# Currently, 257 files have been processed
# Currently, 258 files have been processed
# Currently, 259 files have been processed
# Currently, 260 files have been processed
# Currently, 261 files have been processed
# Currently, 262 files have been processed
# Currently, 263 files have been processed
# Currently, 264 files have been processed
# Currently, 265 files have been processed
# Currently, 266 files have been processed
# Currently, 267 files have been processed
# Currently, 268 files have been processed
# Currently, 269 files have been processed
# Currently, 270 files have been processed
# Currently, 271 files have been processed
# Currently, 272 files have been processed
# Currently, 273 files have been processed
# Currently, 274 files have been processed
# Currently, 275 files have been processed
# Currently, 276 files have been processed
# Currently, 277 files have been processed
# Currently, 278 files have been processed
# Currently, 279 files have been processed
# Currently, 280 files have been processed
# Currently, 281 files have been processed
# Currently, 282 files have been processed
# Currently, 283 files have been processed
# Currently, 284 files have been processed
# Currently, 285 files have been processed
# Currently, 286 files have been processed
# Currently, 287 files have been processed
# Currently, 288 files have been processed
# Currently, 289 files have been processed
# Currently, 290 files have been processed
# Currently, 291 files have been processed
# Currently, 292 files have been processed
# Currently, 293 files have been processed
# Currently, 294 files have been processed
# Currently, 295 files have been processed
# Currently, 296 files have been processed
# Currently, 297 files have been processed
# Currently, 298 files have been processed
# Currently, 299 files have been processed
# Currently, 300 files have been processed
# Currently, 301 files have been processed
# Currently, 302 files have been processed
# Currently, 303 files have been processed
# Currently, 304 files have been processed
# Currently, 305 files have been processed
# Currently, 306 files have been processed
# Currently, 307 files have been processed
# Currently, 308 files have been processed
# Currently, 309 files have been processed
# Currently, 310 files have been processed
# Currently, 311 files have been processed
# Currently, 312 files have been processed
# Currently, 313 files have been processed
# Currently, 314 files have been processed
# Currently, 315 files have been processed
# Currently, 316 files have been processed
# Currently, 317 files have been processed
# Currently, 318 files have been processed
# Currently, 319 files have been processed
# Currently, 320 files have been processed
# Currently, 321 files have been processed
# Currently, 322 files have been processed
# Currently, 323 files have been processed
# Currently, 324 files have been processed
# Currently, 325 files have been processed
# Currently, 326 files have been processed
# Currently, 327 files have been processed
# Currently, 328 files have been processed
# Currently, 329 files have been processed
# Currently, 330 files have been processed
# Currently, 331 files have been processed
# Currently, 332 files have been processed
# Currently, 333 files have been processed
# Currently, 334 files have been processed
# Currently, 335 files have been processed
# Currently, 336 files have been processed
# Currently, 337 files have been processed
# Currently, 338 files have been processed
# Currently, 339 files have been processed
# Currently, 340 files have been processed
# Currently, 341 files have been processed
# Currently, 342 files have been processed
# Currently, 343 files have been processed
# Currently, 344 files have been processed
# Currently, 345 files have been processed
# Currently, 346 files have been processed
# Currently, 347 files have been processed
# Currently, 348 files have been processed
# Currently, 349 files have been processed
# Currently, 350 files have been processed
# Currently, 351 files have been processed
# Currently, 352 files have been processed
# Currently, 353 files have been processed
# Currently, 354 files have been processed
# Currently, 355 files have been processed
# Currently, 356 files have been processed
# Currently, 357 files have been processed
# Currently, 358 files have been processed
# Currently, 359 files have been processed
# Currently, 360 files have been processed
# Currently, 361 files have been processed
# Currently, 362 files have been processed
# Currently, 363 files have been processed
# Currently, 364 files have been processed
# Currently, 365 files have been processed
# Currently, 366 files have been processed
# Currently, 367 files have been processed
# Currently, 368 files have been processed
# Currently, 369 files have been processed
# Currently, 370 files have been processed
# Currently, 371 files have been processed
# Currently, 372 files have been processed
# Currently, 373 files have been processed
# Currently, 374 files have been processed
# Currently, 375 files have been processed
# Currently, 376 files have been processed
# Currently, 377 files have been processed
# Currently, 378 files have been processed
# Currently, 379 files have been processed
# Currently, 380 files have been processed
# Currently, 381 files have been processed
# Currently, 382 files have been processed
# Currently, 383 files have been processed
# Currently, 384 files have been processed
# Currently, 385 files have been processed
# Currently, 386 files have been processed
# Currently, 387 files have been processed
# Currently, 388 files have been processed
# Currently, 389 files have been processed
# Currently, 390 files have been processed
# Currently, 391 files have been processed
# Currently, 392 files have been processed
# Currently, 393 files have been processed
# Currently, 394 files have been processed
# Currently, 395 files have been processed
# Currently, 396 files have been processed
# Currently, 397 files have been processed
# Currently, 398 files have been processed
# Currently, 399 files have been processed
# Currently, 400 files have been processed
# Currently, 401 files have been processed
# Currently, 402 files have been processed
# Currently, 403 files have been processed
# Currently, 404 files have been processed
# Currently, 405 files have been processed
# Currently, 406 files have been processed
# Currently, 407 files have been processed
# Currently, 408 files have been processed
# Currently, 409 files have been processed
# Currently, 410 files have been processed
# Currently, 411 files have been processed
# Currently, 412 files have been processed
# Currently, 413 files have been processed
# Currently, 414 files have been processed
# Currently, 415 files have been processed
# Currently, 416 files have been processed
# Currently, 417 files have been processed
# Currently, 418 files have been processed
# Currently, 419 files have been processed
# Currently, 420 files have been processed
# Currently, 421 files have been processed
# Currently, 422 files have been processed
# Currently, 423 files have been processed
# Currently, 424 files have been processed
# Currently, 425 files have been processed
# Currently, 426 files have been processed
# Currently, 427 files have been processed
# Currently, 428 files have been processed
# Currently, 429 files have been processed
# Currently, 430 files have been processed
# Currently, 431 files have been processed
# Currently, 432 files have been processed
# Currently, 433 files have been processed
# Currently, 434 files have been processed
# Currently, 435 files have been processed
# Currently, 436 files have been processed
# Currently, 437 files have been processed
# Currently, 438 files have been processed
# Currently, 439 files have been processed
# Currently, 440 files have been processed
# Currently, 441 files have been processed
# Currently, 442 files have been processed
# Currently, 443 files have been processed
# Currently, 444 files have been processed
# Currently, 445 files have been processed
# Currently, 446 files have been processed
# Currently, 447 files have been processed
# Currently, 448 files have been processed
# Currently, 449 files have been processed
# Currently, 450 files have been processed
# Currently, 451 files have been processed
# Currently, 452 files have been processed
# Currently, 453 files have been processed
# Currently, 454 files have been processed
# Currently, 455 files have been processed
# Currently, 456 files have been processed
# Currently, 457 files have been processed
# Currently, 458 files have been processed
# Currently, 459 files have been processed
# Currently, 460 files have been processed
# Currently, 461 files have been processed
# Currently, 462 files have been processed
# Currently, 463 files have been processed
# Currently, 464 files have been processed
# Currently, 465 files have been processed
# Currently, 466 files have been processed
# Currently, 467 files have been processed
# Currently, 468 files have been processed
# Currently, 469 files have been processed
# Currently, 470 files have been processed
# Currently, 471 files have been processed
# Currently, 472 files have been processed
# Currently, 473 files have been processed
# Currently, 474 files have been processed
# Currently, 475 files have been processed
# Currently, 476 files have been processed
# Currently, 477 files have been processed
# Currently, 478 files have been processed
# Currently, 479 files have been processed
# Currently, 480 files have been processed
# Currently, 481 files have been processed
# Currently, 482 files have been processed
# Currently, 483 files have been processed
# Currently, 484 files have been processed
# Currently, 485 files have been processed
# Currently, 486 files have been processed
# Currently, 487 files have been processed
# Currently, 488 files have been processed
# Currently, 489 files have been processed
# Currently, 490 files have been processed
# Currently, 491 files have been processed
# Currently, 492 files have been processed
# Currently, 493 files have been processed
# Currently, 494 files have been processed
# Currently, 495 files have been processed
# Currently, 496 files have been processed
# Currently, 497 files have been processed
# Currently, 498 files have been processed
# Currently, 499 files have been processed
# Currently, 500 files have been processed
# Currently, 501 files have been processed
# Currently, 502 files have been processed
# Currently, 503 files have been processed
# Currently, 504 files have been processed
# Currently, 505 files have been processed
# Currently, 506 files have been processed
# Currently, 507 files have been processed
# Currently, 508 files have been processed
# Currently, 509 files have been processed
# Currently, 510 files have been processed
# Currently, 511 files have been processed
# Currently, 512 files have been processed
# Currently, 513 files have been processed
# Currently, 514 files have been processed
# Currently, 515 files have been processed
# Currently, 516 files have been processed
# Currently, 517 files have been processed
# Currently, 518 files have been processed
# Currently, 519 files have been processed
# Currently, 520 files have been processed
# Currently, 521 files have been processed
# Currently, 522 files have been processed
# Currently, 523 files have been processed
# Currently, 524 files have been processed
# Currently, 525 files have been processed
# Currently, 526 files have been processed
# Currently, 527 files have been processed
# Currently, 528 files have been processed
# Currently, 529 files have been processed
# Currently, 530 files have been processed
# Currently, 531 files have been processed
# Currently, 532 files have been processed
# Currently, 533 files have been processed
# Currently, 534 files have been processed
# Currently, 535 files have been processed
# Currently, 536 files have been processed
# Currently, 537 files have been processed
# Currently, 538 files have been processed
# Currently, 539 files have been processed
# Currently, 540 files have been processed
# Currently, 541 files have been processed
# Currently, 542 files have been processed
# Currently, 543 files have been processed
# Currently, 544 files have been processed
# Currently, 545 files have been processed
# Currently, 546 files have been processed
# Currently, 547 files have been processed
# Currently, 548 files have been processed
# Currently, 549 files have been processed
# Currently, 550 files have been processed
# Currently, 551 files have been processed
# Currently, 552 files have been processed
# Currently, 553 files have been processed
# Currently, 554 files have been processed
# Currently, 555 files have been processed
# Currently, 556 files have been processed
# Currently, 557 files have been processed
# Currently, 558 files have been processed
# Currently, 559 files have been processed
# Currently, 560 files have been processed
# Currently, 561 files have been processed
# Currently, 562 files have been processed
# Currently, 563 files have been processed
# Currently, 564 files have been processed
# Currently, 565 files have been processed
# Currently, 566 files have been processed
# Currently, 567 files have been processed
# Currently, 568 files have been processed
# Currently, 569 files have been processed
# Currently, 570 files have been processed
# Currently, 571 files have been processed
# Currently, 572 files have been processed
# Currently, 573 files have been processed
# Currently, 574 files have been processed
# Currently, 575 files have been processed
# Currently, 576 files have been processed
# Currently, 577 files have been processed
# Currently, 578 files have been processed
# Currently, 579 files have been processed
# Currently, 580 files have been processed
# Currently, 581 files have been processed
# Currently, 582 files have been processed
# Currently, 583 files have been processed
# Currently, 584 files have been processed
# Currently, 585 files have been processed
# Currently, 586 files have been processed
# Currently, 587 files have been processed
# Currently, 588 files have been processed
# Currently, 589 files have been processed
# Currently, 590 files have been processed
# Currently, 591 files have been processed
# Currently, 592 files have been processed
# Currently, 593 files have been processed
# Currently, 594 files have been processed
# Currently, 595 files have been processed
# Currently, 596 files have been processed
# Currently, 597 files have been processed
# Currently, 598 files have been processed
# Currently, 599 files have been processed
# Currently, 600 files have been processed
# Currently, 601 files have been processed
# Currently, 602 files have been processed
# Currently, 603 files have been processed
# Currently, 604 files have been processed
# Currently, 605 files have been processed
# Currently, 606 files have been processed
# Currently, 607 files have been processed
# Currently, 608 files have been processed
# Currently, 609 files have been processed
# Currently, 610 files have been processed
# Currently, 611 files have been processed
# Currently, 612 files have been processed
# Currently, 613 files have been processed
# Currently, 614 files have been processed
# Currently, 615 files have been processed
# Currently, 616 files have been processed
# Currently, 617 files have been processed
# Currently, 618 files have been processed
# Currently, 619 files have been processed
# Currently, 620 files have been processed
# Currently, 621 files have been processed
# Currently, 622 files have been processed
# Currently, 623 files have been processed
# Currently, 624 files have been processed
# Currently, 625 files have been processed
# Currently, 626 files have been processed
# Currently, 627 files have been processed
# Currently, 628 files have been processed
# Currently, 629 files have been processed
# Currently, 630 files have been processed
# Currently, 631 files have been processed
# Currently, 632 files have been processed
# Currently, 633 files have been processed
# Currently, 634 files have been processed
# Currently, 635 files have been processed
# Currently, 636 files have been processed
# Currently, 637 files have been processed
# Currently, 638 files have been processed
# Currently, 639 files have been processed
# Currently, 640 files have been processed
# Currently, 641 files have been processed
# Currently, 642 files have been processed
# Currently, 643 files have been processed
# Currently, 644 files have been processed
# Currently, 645 files have been processed
# Currently, 646 files have been processed
# Currently, 647 files have been processed
# Currently, 648 files have been processed
# Currently, 649 files have been processed
# Currently, 650 files have been processed
# Currently, 651 files have been processed
# Currently, 652 files have been processed
# Currently, 653 files have been processed
# Currently, 654 files have been processed
# Currently, 655 files have been processed
# Currently, 656 files have been processed
# Currently, 657 files have been processed
# Currently, 658 files have been processed
# Currently, 659 files have been processed
# Currently, 660 files have been processed
# Currently, 661 files have been processed
# Currently, 662 files have been processed
# Currently, 663 files have been processed
# Currently, 664 files have been processed
# Currently, 665 files have been processed
# Currently, 666 files have been processed
# Currently, 667 files have been processed
# Currently, 668 files have been processed
# Currently, 669 files have been processed
# Currently, 670 files have been processed
# Currently, 671 files have been processed
# Currently, 672 files have been processed
# Currently, 673 files have been processed
# Currently, 674 files have been processed
# Currently, 675 files have been processed
# Currently, 676 files have been processed
# Currently, 677 files have been processed
# Currently, 678 files have been processed
# Currently, 679 files have been processed
# Currently, 680 files have been processed
# Currently, 681 files have been processed
# Currently, 682 files have been processed
# Currently, 683 files have been processed
# Currently, 684 files have been processed
# Currently, 685 files have been processed
# Currently, 686 files have been processed
# Currently, 687 files have been processed
# Currently, 688 files have been processed
# Currently, 689 files have been processed
# Currently, 690 files have been processed
# Currently, 691 files have been processed
# Currently, 692 files have been processed
# Currently, 693 files have been processed
# Currently, 694 files have been processed
# Currently, 695 files have been processed
# Currently, 696 files have been processed
# Currently, 697 files have been processed
# Currently, 698 files have been processed
# Currently, 699 files have been processed
# Currently, 700 files have been processed
# Currently, 701 files have been processed
# Currently, 702 files have been processed
# Currently, 703 files have been processed
# Currently, 704 files have been processed
# Currently, 705 files have been processed
# Currently, 706 files have been processed
# Currently, 707 files have been processed
# Currently, 708 files have been processed
# Currently, 709 files have been processed
# Currently, 710 files have been processed
# Currently, 711 files have been processed
# Currently, 712 files have been processed
# Currently, 713 files have been processed
# Currently, 714 files have been processed
# Currently, 715 files have been processed
# Currently, 716 files have been processed
# Currently, 717 files have been processed
# Currently, 718 files have been processed
# Currently, 719 files have been processed
# Currently, 720 files have been processed
# Currently, 721 files have been processed
# Currently, 722 files have been processed
# Currently, 723 files have been processed
# Currently, 724 files have been processed
# Currently, 725 files have been processed
# Currently, 726 files have been processed
# Currently, 727 files have been processed
# Currently, 728 files have been processed
# Currently, 729 files have been processed
# Currently, 730 files have been processed
# Currently, 731 files have been processed
# Currently, 732 files have been processed
# Currently, 733 files have been processed
# Currently, 734 files have been processed
# Currently, 735 files have been processed
# Currently, 736 files have been processed
# Currently, 737 files have been processed
# Currently, 738 files have been processed
# Currently, 739 files have been processed
# Currently, 740 files have been processed
# Currently, 741 files have been processed
# Currently, 742 files have been processed
# Currently, 743 files have been processed
# Currently, 744 files have been processed
# Currently, 745 files have been processed
# Currently, 746 files have been processed
# Currently, 747 files have been processed
# Currently, 748 files have been processed
# Currently, 749 files have been processed
# Currently, 750 files have been processed
# Currently, 751 files have been processed
# Currently, 752 files have been processed
# Currently, 753 files have been processed
# Currently, 754 files have been processed
# Currently, 755 files have been processed
# Currently, 756 files have been processed
# Currently, 757 files have been processed
# Currently, 758 files have been processed
# Currently, 759 files have been processed
# Currently, 760 files have been processed
# Currently, 761 files have been processed
# Currently, 762 files have been processed
# Currently, 763 files have been processed
# Currently, 764 files have been processed
# Currently, 765 files have been processed
# Currently, 766 files have been processed
# Currently, 767 files have been processed
# Currently, 768 files have been processed
# Currently, 769 files have been processed
# Currently, 770 files have been processed
# Currently, 771 files have been processed
# Currently, 772 files have been processed
# Currently, 773 files have been processed
# Currently, 774 files have been processed
# Currently, 775 files have been processed
# Currently, 776 files have been processed
# Currently, 777 files have been processed
# Currently, 778 files have been processed
# Currently, 779 files have been processed
# Currently, 780 files have been processed
# Currently, 781 files have been processed
# Currently, 782 files have been processed
# Currently, 783 files have been processed
# Currently, 784 files have been processed
# Currently, 785 files have been processed
# Currently, 786 files have been processed
# Currently, 787 files have been processed
# Currently, 788 files have been processed
# Currently, 789 files have been processed
# Currently, 790 files have been processed
# Currently, 791 files have been processed
# Currently, 792 files have been processed
# Currently, 793 files have been processed
# Currently, 794 files have been processed
# Currently, 795 files have been processed
# Currently, 796 files have been processed
# Currently, 797 files have been processed
# Currently, 798 files have been processed
# Currently, 799 files have been processed
# Currently, 800 files have been processed
# Currently, 801 files have been processed
# Currently, 802 files have been processed
# Currently, 803 files have been processed
# Currently, 804 files have been processed
# Currently, 805 files have been processed
# Currently, 806 files have been processed
# Currently, 807 files have been processed
# Currently, 808 files have been processed
# Currently, 809 files have been processed
# Currently, 810 files have been processed
# Currently, 811 files have been processed
# Currently, 812 files have been processed
# Currently, 813 files have been processed
# Currently, 814 files have been processed
# Currently, 815 files have been processed
# Currently, 816 files have been processed
# Currently, 817 files have been processed
# Currently, 818 files have been processed
# Currently, 819 files have been processed
# Currently, 820 files have been processed
# Currently, 821 files have been processed
# Currently, 822 files have been processed
# Currently, 823 files have been processed
# Currently, 824 files have been processed
# Currently, 825 files have been processed
# Currently, 826 files have been processed
# Currently, 827 files have been processed
# Currently, 828 files have been processed
# Currently, 829 files have been processed
# Currently, 830 files have been processed
# Currently, 831 files have been processed
# Currently, 832 files have been processed
# Currently, 833 files have been processed
# Currently, 834 files have been processed
# Currently, 835 files have been processed
# Currently, 836 files have been processed
# Currently, 837 files have been processed
# Currently, 838 files have been processed
# Currently, 839 files have been processed
# Currently, 840 files have been processed
# Currently, 841 files have been processed
# Currently, 842 files have been processed
# Currently, 843 files have been processed
# Currently, 844 files have been processed
# Currently, 845 files have been processed
# Currently, 846 files have been processed
# Currently, 847 files have been processed
# Currently, 848 files have been processed
# Currently, 849 files have been processed
# Currently, 850 files have been processed
# Currently, 851 files have been processed
# Currently, 852 files have been processed
# Currently, 853 files have been processed
# Currently, 854 files have been processed
# Currently, 855 files have been processed
# Currently, 856 files have been processed
# Currently, 857 files have been processed
# Currently, 858 files have been processed
# Currently, 859 files have been processed
# Currently, 860 files have been processed
# Currently, 861 files have been processed
# Currently, 862 files have been processed
# Currently, 863 files have been processed
# Currently, 864 files have been processed
# Currently, 865 files have been processed
# Currently, 866 files have been processed
# Currently, 867 files have been processed
# Currently, 868 files have been processed
# Currently, 869 files have been processed
# Currently, 870 files have been processed
# Currently, 871 files have been processed
# Currently, 872 files have been processed
# Currently, 873 files have been processed
# Currently, 874 files have been processed
# Currently, 875 files have been processed
# Currently, 876 files have been processed
# Currently, 877 files have been processed
# Currently, 878 files have been processed
# Currently, 879 files have been processed
# Currently, 880 files have been processed
# Currently, 881 files have been processed
# Currently, 882 files have been processed
# Currently, 883 files have been processed
# Currently, 884 files have been processed
# Currently, 885 files have been processed
# Currently, 886 files have been processed
# Currently, 887 files have been processed
# Currently, 888 files have been processed
# Currently, 889 files have been processed
# Currently, 890 files have been processed
# Currently, 891 files have been processed
# Currently, 892 files have been processed
# Currently, 893 files have been processed
# Currently, 894 files have been processed
# Currently, 895 files have been processed
# Currently, 896 files have been processed
# Currently, 897 files have been processed
# Currently, 898 files have been processed
# Currently, 899 files have been processed
# Currently, 900 files have been processed
# Currently, 901 files have been processed
# Currently, 902 files have been processed
# Currently, 903 files have been processed
# Currently, 904 files have been processed
# Currently, 905 files have been processed
# Currently, 906 files have been processed
# Currently, 907 files have been processed
# Currently, 908 files have been processed
# Currently, 909 files have been processed
# Currently, 910 files have been processed
# Currently, 911 files have been processed
# Currently, 912 files have been processed
# Currently, 913 files have been processed
# Currently, 914 files have been processed
# Currently, 915 files have been processed
# Currently, 916 files have been processed
# Currently, 917 files have been processed
# Currently, 918 files have been processed
# Currently, 919 files have been processed
# Currently, 920 files have been processed
# Currently, 921 files have been processed
# Currently, 922 files have been processed
# Currently, 923 files have been processed
# Currently, 924 files have been processed
# Currently, 925 files have been processed
# Currently, 926 files have been processed
# Currently, 927 files have been processed
# Currently, 928 files have been processed
# Currently, 929 files have been processed
# Currently, 930 files have been processed
# Currently, 931 files have been processed
# Currently, 932 files have been processed
# Currently, 933 files have been processed
# Currently, 934 files have been processed
# Currently, 935 files have been processed
# Currently, 936 files have been processed
# Currently, 937 files have been processed
# Currently, 938 files have been processed
# Currently, 939 files have been processed
# Currently, 940 files have been processed
# Currently, 941 files have been processed
# Currently, 942 files have been processed
# Currently, 943 files have been processed
# Currently, 944 files have been processed
# Currently, 945 files have been processed
# Currently, 946 files have been processed
# Currently, 947 files have been processed
# Currently, 948 files have been processed
# Currently, 949 files have been processed
# Currently, 950 files have been processed
# Currently, 951 files have been processed
# Currently, 952 files have been processed
# Currently, 953 files have been processed
# Currently, 954 files have been processed
# Currently, 955 files have been processed
# Currently, 956 files have been processed
# Currently, 957 files have been processed
# Currently, 958 files have been processed
# Currently, 959 files have been processed
# Currently, 960 files have been processed
# Currently, 961 files have been processed
# Currently, 962 files have been processed
# Currently, 963 files have been processed
# Currently, 964 files have been processed
# Currently, 965 files have been processed
# Currently, 966 files have been processed
# Currently, 967 files have been processed
# Currently, 968 files have been processed
# Currently, 969 files have been processed
# Currently, 970 files have been processed
# Currently, 971 files have been processed
# Currently, 972 files have been processed
# Currently, 973 files have been processed
# Currently, 974 files have been processed
# Currently, 975 files have been processed
# Currently, 976 files have been processed
# Currently, 977 files have been processed
# Currently, 978 files have been processed
# Currently, 979 files have been processed
# Currently, 980 files have been processed
# Currently, 981 files have been processed
# Currently, 982 files have been processed
# Currently, 983 files have been processed
# Currently, 984 files have been processed
# Currently, 985 files have been processed
# Currently, 986 files have been processed
# Currently, 987 files have been processed
# Currently, 988 files have been processed
# Currently, 989 files have been processed
# Currently, 990 files have been processed
# Currently, 991 files have been processed
# Currently, 992 files have been processed
# Currently, 993 files have been processed
# Currently, 994 files have been processed
# Currently, 995 files have been processed
# Currently, 996 files have been processed
# Currently, 997 files have been processed
# Currently, 998 files have been processed
# Currently, 999 files have been processed
# Currently, 1000 files have been processed
# Currently, 1001 files have been processed
# Currently, 1002 files have been processed
# Currently, 1003 files have been processed
# Currently, 1004 files have been processed
# Currently, 1005 files have been processed
# Currently, 1006 files have been processed
# Currently, 1007 files have been processed
# Currently, 1008 files have been processed
# Currently, 1009 files have been processed
# Currently, 1010 files have been processed
# Currently, 1011 files have been processed
# Currently, 1012 files have been processed
# Currently, 1013 files have been processed
# Currently, 1014 files have been processed
# Currently, 1015 files have been processed
# Currently, 1016 files have been processed
# Currently, 1017 files have been processed
# Currently, 1018 files have been processed
# Currently, 1019 files have been processed
# Currently, 1020 files have been processed
# Currently, 1021 files have been processed
# Currently, 1022 files have been processed
# Currently, 1023 files have been processed
# Currently, 1024 files have been processed
# Currently, 1025 files have been processed
# Currently, 1026 files have been processed
# Currently, 1027 files have been processed
# Currently, 1028 files have been processed
# Currently, 1029 files have been processed
# Currently, 1030 files have been processed
# Currently, 1031 files have been processed
# Currently, 1032 files have been processed
# Currently, 1033 files have been processed
# Currently, 1034 files have been processed
# Currently, 1035 files have been processed
# Currently, 1036 files have been processed
# Currently, 1037 files have been processed
# Currently, 1038 files have been processed
# Currently, 1039 files have been processed
# Currently, 1040 files have been processed
# Currently, 1041 files have been processed
# Currently, 1042 files have been processed
# Currently, 1043 files have been processed
# Currently, 1044 files have been processed
# Currently, 1045 files have been processed
# Currently, 1046 files have been processed
# Currently, 1047 files have been processed
# Currently, 1048 files have been processed
# Currently, 1049 files have been processed
# Currently, 1050 files have been processed
# Currently, 1051 files have been processed
# Currently, 1052 files have been processed
# Currently, 1053 files have been processed
# Currently, 1054 files have been processed
# Currently, 1055 files have been processed
# Currently, 1056 files have been processed
# Currently, 1057 files have been processed
# Currently, 1058 files have been processed
# Currently, 1059 files have been processed
# Currently, 1060 files have been processed
# Currently, 1061 files have been processed
# Currently, 1062 files have been processed
# Currently, 1063 files have been processed
# Currently, 1064 files have been processed
# Currently, 1065 files have been processed
# Currently, 1066 files have been processed
# Currently, 1067 files have been processed
# Currently, 1068 files have been processed
# Currently, 1069 files have been processed
# Currently, 1070 files have been processed
# Currently, 1071 files have been processed
# Currently, 1072 files have been processed
# Currently, 1073 files have been processed
# Currently, 1074 files have been processed
# Currently, 1075 files have been processed
# Currently, 1076 files have been processed
# Currently, 1077 files have been processed
# Currently, 1078 files have been processed
# Currently, 1079 files have been processed
# Currently, 1080 files have been processed
# Currently, 1081 files have been processed
# Currently, 1082 files have been processed
# Currently, 1083 files have been processed
# Currently, 1084 files have been processed
# Currently, 1085 files have been processed
# Currently, 1086 files have been processed
# Currently, 1087 files have been processed
# Currently, 1088 files have been processed
# Currently, 1089 files have been processed
# Currently, 1090 files have been processed
# Currently, 1091 files have been processed
# Currently, 1092 files have been processed
# Currently, 1093 files have been processed
# Currently, 1094 files have been processed
# Currently, 1095 files have been processed
# Currently, 1096 files have been processed
# Currently, 1097 files have been processed
# Currently, 1098 files have been processed
# Currently, 1099 files have been processed
# Currently, 1100 files have been processed
# Currently, 1101 files have been processed
# Currently, 1102 files have been processed
# Currently, 1103 files have been processed
# Currently, 1104 files have been processed
# Currently, 1105 files have been processed
# Currently, 1106 files have been processed
# Currently, 1107 files have been processed
# Currently, 1108 files have been processed
# Currently, 1109 files have been processed
# Currently, 1110 files have been processed
# Currently, 1111 files have been processed
# Currently, 1112 files have been processed
# Currently, 1113 files have been processed
# Currently, 1114 files have been processed
# Currently, 1115 files have been processed
# Currently, 1116 files have been processed
# Currently, 1117 files have been processed
# Currently, 1118 files have been processed
# Currently, 1119 files have been processed
# Currently, 1120 files have been processed
# Currently, 1121 files have been processed
# Currently, 1122 files have been processed
# Currently, 1123 files have been processed
# Currently, 1124 files have been processed
# Currently, 1125 files have been processed
# Currently, 1126 files have been processed
# Currently, 1127 files have been processed
# Currently, 1128 files have been processed
# Currently, 1129 files have been processed
# Currently, 1130 files have been processed
# Currently, 1131 files have been processed
# Currently, 1132 files have been processed
# Currently, 1133 files have been processed
# Currently, 1134 files have been processed
# Currently, 1135 files have been processed
# Currently, 1136 files have been processed
# Currently, 1137 files have been processed
# Currently, 1138 files have been processed
# Currently, 1139 files have been processed
# Currently, 1140 files have been processed
# Currently, 1141 files have been processed
# Currently, 1142 files have been processed
# Currently, 1143 files have been processed
# Currently, 1144 files have been processed
# Currently, 1145 files have been processed
# Currently, 1146 files have been processed
# Currently, 1147 files have been processed
# Currently, 1148 files have been processed
# Currently, 1149 files have been processed

# %%
output_df
# Out:
#                 LOG_ID                                    ARC_wavefeature  \
# 0     00fbb475a02e94c3      [252.12, 32.0, 220.11, 7.25, 12081.74, 50.28]
# 1     011e00acde3a3342  [16279.61, 1685.74, 14593.87, 8.29, 185471079....
# 2     0124e746e00e3b4a  [1520.99, 189.51, 1331.48, 1.55, 415709.79, 48...
# 3     01953a9111bff808  [1304.1, 171.75, 1132.35, 14.92, 428938.54, 45...
# 4     01dc302bc8104d42  [1958.25, 290.57, 1667.67, 0.55, 1068265.31, 4...
# ...                ...                                                ...
# 1143  ff5c0ba0edf25cf2  [3465.44, 476.34, 2989.1, 0.64, 2393360.64, 45...
# 1144  ff9d82108883542a       [207.4, 26.07, 181.34, 7.36, 7376.23, 46.12]
# 1145  ffc167ad138cf4a7  [2423.18, 309.71, 2113.47, 0.71, 1715274.39, 4...
# 1146  ffcb585a8a103c92       [173.08, 26.02, 147.06, 3.2, 5698.56, 45.13]
# 1147  ffcc94cd9bc06e15  [15660.18, 1684.57, 13975.61, 16.63, 172302208...
#
#                                ECG_wavefeature
# 0         [322.92, 434.57, 869.92, 0.0, 69.76]
# 1                  [0.64, 0.6, 2.27, 0.0, 6.3]
# 2     [1452.14, 1582.2, 5244.57, 0.24, 158.34]
# 3                [0.17, 0.17, 0.61, 0.0, 2.61]
# 4                [0.36, 0.47, 0.91, 0.0, 4.25]
# ...                                        ...
# 1143              [1.1, 1.59, 1.99, 0.0, 4.75]
# 1144            [0.01, 0.02, 0.02, 0.24, 0.48]
# 1145            [0.52, 0.65, 1.22, 7.92, 6.55]
# 1146            [0.01, 0.01, 0.01, 1.92, 0.44]
# 1147             [1.37, 1.76, 3.99, 0.0, 8.45]
#
# [1148 rows x 3 columns]

# %%
arc_columns = ['systolic_peak', 'diastolic_peak', 'pulse_amplitude', 'arc_peak_frequency', 'arc_spectral_energy', 'arc_bandwidth']
ecg_columns = ['qrs_freq_power', 'vf_freq_power', 'vt_freq_power', 'qrs_peak_freq', 'ecg_std_magnitude']

output_df[arc_columns] = output_df['ARC_wavefeature'].apply(pd.Series)
output_df[ecg_columns] = output_df['ECG_wavefeature'].apply(pd.Series)


output_df.drop(['ARC_wavefeature', 'ECG_wavefeature'], axis=1, inplace=True)
output_df
# Out:
#                 LOG_ID  systolic_peak  diastolic_peak  pulse_amplitude  \
# 0     00fbb475a02e94c3         252.12           32.00           220.11
# 1     011e00acde3a3342       16279.61         1685.74         14593.87
# 2     0124e746e00e3b4a        1520.99          189.51          1331.48
# 3     01953a9111bff808        1304.10          171.75          1132.35
# 4     01dc302bc8104d42        1958.25          290.57          1667.67
# ...                ...            ...             ...              ...
# 1143  ff5c0ba0edf25cf2        3465.44          476.34          2989.10
# 1144  ff9d82108883542a         207.40           26.07           181.34
# 1145  ffc167ad138cf4a7        2423.18          309.71          2113.47
# 1146  ffcb585a8a103c92         173.08           26.02           147.06
# 1147  ffcc94cd9bc06e15       15660.18         1684.57         13975.61
#
#       arc_peak_frequency  arc_spectral_energy  arc_bandwidth  qrs_freq_power  \
# 0                   7.25         1.208174e+04          50.28          322.92
# 1                   8.29         1.854711e+08          47.16            0.64
# 2                   1.55         4.157098e+05          48.78         1452.14
# 3                  14.92         4.289385e+05          45.24            0.17
# 4                   0.55         1.068265e+06          45.21            0.36
# ...                  ...                  ...            ...             ...
# 1143                0.64         2.393361e+06          45.27            1.10
# 1144                7.36         7.376230e+03          46.12            0.01
# 1145                0.71         1.715274e+06          45.34            0.52
# 1146                3.20         5.698560e+03          45.13            0.01
# 1147               16.63         1.723022e+08          47.14            1.37
#
#       vf_freq_power  vt_freq_power  qrs_peak_freq  ecg_std_magnitude
# 0            434.57         869.92           0.00              69.76
# 1              0.60           2.27           0.00               6.30
# 2           1582.20        5244.57           0.24             158.34
# 3              0.17           0.61           0.00               2.61
# 4              0.47           0.91           0.00               4.25
# ...             ...            ...            ...                ...
# 1143           1.59           1.99           0.00               4.75
# 1144           0.02           0.02           0.24               0.48
# 1145           0.65           1.22           7.92               6.55
# 1146           0.01           0.01           1.92               0.44
# 1147           1.76           3.99           0.00               8.45
#
# [1148 rows x 12 columns]

# %% [markdown]
# The waveform data is too large and using sharding storage. Therefore, the waveform is been processed seperatly on differnt laptops, and required to concat to generate a complete waveform feature extraction results

# %%
file_path = r'C:\Users\rodge\OneDrive\Desktop\SML\Group Project\comp90051\data\rawData\processedData\output_part1.csv'
output_1 = pd.read_csv(file_path)
output_df = pd.concat([output_1, output_df], ignore_index=True)

# %%
folder_path = r'C:\Users\rodge\OneDrive\Desktop\SML\Group Project\comp90051\data\processedData'
file_name = 'waveform_features.csv'

full_path = f'{folder_path}\\{file_name}'
output_df.to_csv(full_path, index=False)
